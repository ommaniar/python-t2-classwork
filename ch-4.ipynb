# %%
data = {
    "l":[10,13,20,22],
    "b":[15,20,20,14]
}

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(data)
df["area"] = [i*j for i,j in zip(df.l,df.b)]

# %%
df["a"] = df.l * df.b

# %%
df
# Out:
#     l   b  area    a
# 0  10  15   150  150
# 1  13  20   260  260
# 2  20  20   400  400
# 3  22  14   308  308

# %%
df["size"]=np.where(df["a"] >= 400,"L",
                    np.where(df["a"]>300,"m",
                             np.where(df["a"] > 200,"S",
                                      np.where(df["a"]>100,"k","very small"))))

# %%
df
# Out:
#     l   b  area    a size
# 0  10  15   150  150    k
# 1  13  20   260  260    S
# 2  20  20   400  400    L
# 3  22  14   308  308    m

# %%
df = pd.read_csv("files/housing.csv")
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# crim          0
# zn            0
# indus         0
# chas          0
# nox           0
# rm            0
# age           0
# dis           0
# rad           0
# tax           0
# ptratio       0
# black         0
# lstat         0
# medv          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop("Unnamed: 0",axis=1)

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# black   -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# lstat    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# medv    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               dis       rad       tax   ptratio     black     lstat      medv
# crim    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# zn       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# indus   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# chas    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# nox     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# rm       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# age     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# dis      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# rad     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# tax     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# ptratio -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# black    0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# lstat   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# medv     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
x = pd.DataFrame(df.lstat)
y = pd.DataFrame(df.medv)

# %%
x = df.drop("medv",axis=1)
y = df[["medv"]]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=3)

# %%
x_train.shape,x_test.shape,y_train.shape, y_test.shape
# Out:
# ((404, 13), (102, 13), (404, 1), (102, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
mod = LinearRegression()
mod.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = mod.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test,y_pred)

# %%
mse,r2
# Out:
# (16.943073013833896, 0.7952617563243845)

# %%
print(mod.coef_)
print(mod.intercept_)
# Out:
# [[-1.23897571e-01  4.81822924e-02 -4.74497796e-02  3.36938950e+00
#   -1.56635488e+01  3.59419367e+00 -9.33206067e-03 -1.47089101e+00
#    3.05053544e-01 -1.08397039e-02 -9.08791339e-01  1.00352939e-02
#   -4.77714677e-01]]
# [35.86168335]

# %%
a = [[0.1,1,2,3,2,1,50,4,300,5,30,20,5]]
p = mod.predict(a)
p
# Out:
# D:\Softwares\Anaconda\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[73.83793069]])

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
df = pd.read_csv("files/CarPrice_Assignment.csv")
display(df.head())
df.shape
display(df.dtypes)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df.nunique()
# Out:
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
df.fueltype.value_counts()
# Out:
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
df.aspiration.value_counts()
# Out:
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64

# %%
df.doornumber.value_counts()
# Out:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64

# %%
df.carbody.value_counts()
# Out:
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
df.drivewheel.value_counts()
# Out:
# drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64

# %%
df.enginelocation.value_counts()
# Out:
# enginelocation
# front    202
# rear       3
# Name: count, dtype: int64

# %%
df.enginetype.value_counts()
# Out:
# enginetype
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: count, dtype: int64

# %%
df.fuelsystem.value_counts()
# Out:
# fuelsystem
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64

# %%
df.CarName.value_counts()
# Out:
# CarName
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: count, Length: 147, dtype: int64

# %%
df.cylindernumber.value_counts()
# Out:
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: count, dtype: int64

# %%
df["company"]=[x.split()[0] for x in df["CarName"]]

# %%
# df["company"]=df["CarName"].apply(lambda x:x.split('')[0])

# %%
df.company.value_counts()
# Out:
# company
# toyota         32
# nissan         17
# mazda          15
# mitsubishi     13
# honda          13
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# volkswagen      9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         4
# isuzu           4
# alfa-romero     3
# jaguar          3
# chevrolet       3
# renault         2
# maxda           2
# vw              2
# porcshce        1
# mercury         1
# vokswagen       1
# Nissan          1
# Name: count, dtype: int64

# %%
df.company.nunique()
# Out:
# 28

# %%
df.company.replace("toyouta","toyota",inplace=True)

# %%
d = [["maxda","mazda"],["porcshce","porsche"],["vokswagen","volkswagen"],["vw","volkswagen"],["Nissan","nissan"]]
for i in d:
    df.company.replace(i[0],i[1],inplace=True)

# %%
df.company.value_counts()
# Out:
# company
# toyota         32
# nissan         18
# mazda          17
# mitsubishi     13
# honda          13
# volkswagen     12
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Name: count, dtype: int64

# %%
df.company.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='company'>

# %%
sn.countplot(x="company",data=df)
# Out:
# <Axes: xlabel='company', ylabel='count'>

# %%
df_categorial = df.select_dtypes(include=["object"])

# %%
df_categorial
# Out:
#                       CarName fueltype aspiration doornumber      carbody  \
# 0          alfa-romero giulia      gas        std        two  convertible
# 1         alfa-romero stelvio      gas        std        two  convertible
# 2    alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3                 audi 100 ls      gas        std       four        sedan
# 4                  audi 100ls      gas        std       four        sedan
# ..                        ...      ...        ...        ...          ...
# 200           volvo 145e (sw)      gas        std       four        sedan
# 201               volvo 144ea      gas      turbo       four        sedan
# 202               volvo 244dl      gas        std       four        sedan
# 203                 volvo 246   diesel      turbo       four        sedan
# 204               volvo 264gl      gas      turbo       four        sedan
#
#     drivewheel enginelocation enginetype cylindernumber fuelsystem  \
# 0          rwd          front       dohc           four       mpfi
# 1          rwd          front       dohc           four       mpfi
# 2          rwd          front       ohcv            six       mpfi
# 3          fwd          front        ohc           four       mpfi
# 4          4wd          front        ohc           five       mpfi
# ..         ...            ...        ...            ...        ...
# 200        rwd          front        ohc           four       mpfi
# 201        rwd          front        ohc           four       mpfi
# 202        rwd          front       ohcv            six       mpfi
# 203        rwd          front        ohc            six        idi
# 204        rwd          front        ohc           four       mpfi
#
#          company
# 0    alfa-romero
# 1    alfa-romero
# 2    alfa-romero
# 3           audi
# 4           audi
# ..           ...
# 200        volvo
# 201        volvo
# 202        volvo
# 203        volvo
# 204        volvo
#
# [205 rows x 11 columns]

# %%
sn.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
pd.plotting.scatter_matrix( df.select_dtypes(include=["number"]),figsize=[15,15])
plt.plot()
# Out:
# []

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front       88.6  ...
# 1          two  convertible        rwd          front       88.6  ...
# 2          two    hatchback        rwd          front       94.5  ...
# 3         four        sedan        fwd          front       99.8  ...
# 4         four        sedan        4wd          front       99.4  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front      109.1  ...
# 201       four        sedan        rwd          front      109.1  ...
# 202       four        sedan        rwd          front      109.1  ...
# 203       four        sedan        rwd          front      109.1  ...
# 204       four        sedan        rwd          front      109.1  ...
#
#      fuelsystem  boreratio  stroke  compressionratio horsepower peakrpm  \
# 0          mpfi       3.47    2.68               9.0        111    5000
# 1          mpfi       3.47    2.68               9.0        111    5000
# 2          mpfi       2.68    3.47               9.0        154    5000
# 3          mpfi       3.19    3.40              10.0        102    5500
# 4          mpfi       3.19    3.40               8.0        115    5500
# ..          ...        ...     ...               ...        ...     ...
# 200        mpfi       3.78    3.15               9.5        114    5400
# 201        mpfi       3.78    3.15               8.7        160    5300
# 202        mpfi       3.58    2.87               8.8        134    5500
# 203         idi       3.01    3.40              23.0        106    4800
# 204        mpfi       3.78    3.15               9.5        114    5400
#
#      citympg highwaympg    price      company
# 0         21         27  13495.0  alfa-romero
# 1         21         27  16500.0  alfa-romero
# 2         19         26  16500.0  alfa-romero
# 3         24         30  13950.0         audi
# 4         18         22  17450.0         audi
# ..       ...        ...      ...          ...
# 200       23         28  16845.0        volvo
# 201       19         25  19045.0        volvo
# 202       18         23  21485.0        volvo
# 203       26         27  22470.0        volvo
# 204       19         25  22625.0        volvo
#
# [205 rows x 27 columns]

# %%
scale = ["wheelbase","carlength","carwidth","carheight","curbweight","enginesize","boreratio","stroke","compressionratio","horsepower","peakrpm","citympg","highwaympg","price"]
df
for col in scale:
    df[col] = np.log(df[col])

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front  -0.901825  ...
# 1          two  convertible        rwd          front  -0.901825  ...
# 2          two    hatchback        rwd          front  -0.878763  ...
# 3         four        sedan        fwd          front  -0.860057  ...
# 4         four        sedan        4wd          front  -0.861410  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front  -0.830994  ...
# 201       four        sedan        rwd          front  -0.830994  ...
# 202       four        sedan        rwd          front  -0.830994  ...
# 203       four        sedan        rwd          front  -0.830994  ...
# 204       four        sedan        rwd          front  -0.830994  ...
#
#      fuelsystem  boreratio    stroke  compressionratio horsepower   peakrpm  \
# 0          mpfi   0.218456 -0.014285          0.787195   1.549588  2.142087
# 1          mpfi   0.218456 -0.014285          0.787195   1.549588  2.142087
# 2          mpfi  -0.014285  0.218456          0.787195   1.616801  2.142087
# 3          mpfi   0.148438  0.201941          0.834032   1.531470  2.153215
# 4          mpfi   0.148438  0.201941          0.732099   1.557077  2.153215
# ..          ...        ...       ...               ...        ...       ...
# 200        mpfi   0.284971  0.137501          0.811504   1.555235  2.151082
# 201        mpfi   0.284971  0.137501          0.771645   1.624361  2.148905
# 202        mpfi   0.243231  0.052888          0.776915   1.588794  2.153215
# 203         idi   0.097072  0.201941          1.142787   1.539753  2.137282
# 204        mpfi   0.284971  0.137501          0.811504   1.555235  2.151082
#
#       citympg highwaympg      price      company
# 0    3.044522   3.295837   9.510075  alfa-romero
# 1    3.044522   3.295837   9.711116  alfa-romero
# 2    2.944439   3.258097   9.711116  alfa-romero
# 3    3.178054   3.401197   9.543235         audi
# 4    2.890372   3.091042   9.767095         audi
# ..        ...        ...        ...          ...
# 200  3.135494   3.332205   9.731809        volvo
# 201  2.944439   3.218876   9.854560        volvo
# 202  2.890372   3.135494   9.975110        volvo
# 203  3.258097   3.295837  10.019936        volvo
# 204  2.944439   3.218876  10.026811        volvo
#
# [205 rows x 27 columns]

# %%
# df.drop(columns=["car_ID","symboling","CarName"],inplace=True)
cat_col = ["fueltype","aspiration","doornumber","carbody","drivewheel","enginelocation","carbody","drivewheel","enginelocation","enginetype","cylindernumber","fuelsystem","company"]
df_dummy= pd.get_dummies(df,columns=cat_col)

# %%
df_dummy
# Out:
#                       CarName  wheelbase  carlength  carwidth  carheight  \
# 0          alfa-romero giulia  -0.901825  -0.710183  0.354608   0.305885
# 1         alfa-romero stelvio  -0.901825  -0.710183  0.354608   0.305885
# 2    alfa-romero Quadrifoglio  -0.878763  -0.706771  0.358235   0.319157
# 3                 audi 100 ls  -0.860057  -0.699359  0.360008   0.325646
# 4                  audi 100ls  -0.861410  -0.699359  0.360509   0.325646
# ..                        ...        ...        ...       ...        ...
# 200           volvo 145e (sw)  -0.830994  -0.683834  0.366606   0.329578
# 201               volvo 144ea  -0.830994  -0.683834  0.366368   0.329578
# 202               volvo 244dl  -0.830994  -0.683834  0.366606   0.329578
# 203                 volvo 246  -0.830994  -0.683834  0.366606   0.329578
# 204               volvo 264gl  -0.830994  -0.683834  0.366606   0.329578
#
#      curbweight  enginesize  boreratio    stroke  compressionratio  ...  \
# 0      2.059630    1.582588   0.218456 -0.014285          0.787195  ...
# 1      2.059630    1.582588   0.218456 -0.014285          0.787195  ...
# 2      2.072613    1.614203  -0.014285  0.218456          0.787195  ...
# 3      2.048547    1.545720   0.148438  0.201941          0.834032  ...
# 4      2.072657    1.591815   0.148438  0.201941          0.732099  ...
# ..          ...         ...        ...       ...               ...  ...
# 200    2.078221    1.599137   0.284971  0.137501          0.811504  ...
# 201    2.082259    1.599137   0.284971  0.137501          0.771645  ...
# 202    2.080736    1.639636   0.243231  0.052888          0.776915  ...
# 203    2.088922    1.604774   0.097072  0.201941          1.142787  ...
# 204    2.082789    1.599137   0.284971  0.137501          0.811504  ...
#
#      company_nissan  company_peugeot  company_plymouth  company_porsche  \
# 0             False            False             False            False
# 1             False            False             False            False
# 2             False            False             False            False
# 3             False            False             False            False
# 4             False            False             False            False
# ..              ...              ...               ...              ...
# 200           False            False             False            False
# 201           False            False             False            False
# 202           False            False             False            False
# 203           False            False             False            False
# 204           False            False             False            False
#
#      company_renault  company_saab  company_subaru  company_toyota  \
# 0              False         False           False           False
# 1              False         False           False           False
# 2              False         False           False           False
# 3              False         False           False           False
# 4              False         False           False           False
# ..               ...           ...             ...             ...
# 200            False         False           False           False
# 201            False         False           False           False
# 202            False         False           False           False
# 203            False         False           False           False
# 204            False         False           False           False
#
#      company_volkswagen  company_volvo
# 0                 False          False
# 1                 False          False
# 2                 False          False
# 3                 False          False
# 4                 False          False
# ..                  ...            ...
# 200               False           True
# 201               False           True
# 202               False           True
# 203               False           True
# 204               False           True
#
# [205 rows x 84 columns]

# %%
df_categorial
# Out:
#                       CarName fueltype aspiration doornumber      carbody  \
# 0          alfa-romero giulia      gas        std        two  convertible
# 1         alfa-romero stelvio      gas        std        two  convertible
# 2    alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3                 audi 100 ls      gas        std       four        sedan
# 4                  audi 100ls      gas        std       four        sedan
# ..                        ...      ...        ...        ...          ...
# 200           volvo 145e (sw)      gas        std       four        sedan
# 201               volvo 144ea      gas      turbo       four        sedan
# 202               volvo 244dl      gas        std       four        sedan
# 203                 volvo 246   diesel      turbo       four        sedan
# 204               volvo 264gl      gas      turbo       four        sedan
#
#     drivewheel enginelocation enginetype cylindernumber fuelsystem  \
# 0          rwd          front       dohc           four       mpfi
# 1          rwd          front       dohc           four       mpfi
# 2          rwd          front       ohcv            six       mpfi
# 3          fwd          front        ohc           four       mpfi
# 4          4wd          front        ohc           five       mpfi
# ..         ...            ...        ...            ...        ...
# 200        rwd          front        ohc           four       mpfi
# 201        rwd          front        ohc           four       mpfi
# 202        rwd          front       ohcv            six       mpfi
# 203        rwd          front        ohc            six        idi
# 204        rwd          front        ohc           four       mpfi
#
#          company
# 0    alfa-romero
# 1    alfa-romero
# 2    alfa-romero
# 3           audi
# 4           audi
# ..           ...
# 200        volvo
# 201        volvo
# 202        volvo
# 203        volvo
# 204        volvo
#
# [205 rows x 11 columns]

# %%
x = df_dummy.drop(["price","CarName"],axis=1)
y = df.price
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=3)
m = LinearRegression()
m.fit(x_train,y_train)
y_pred = m.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.9054031880307418
# 0.02851236789983431

# %%
from sklearn.preprocessing import PolynomialFeatures
# linear regression
x = 6* np.random.rand(200,1) -3
y = 0.8 * x ** 2 + 0.9 * x + 2 + np.random.rand(200,1)
plt.plot(x,y,"o")
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=3)
m = LinearRegression()
m.fit(x_train,y_train)
y_pred = m.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.19419878922948708
# 4.996616544530298

# %%
# polynomial regression
poly = PolynomialFeatures(degree=2)
x_train_transform = poly.fit_transform(x_train)
x_test = poly.transform(x_test)
lr = LinearRegression()
lr.fit(x_train_transform,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.9873320925568199
# 0.07855122959501074
